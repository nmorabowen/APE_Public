# %%
import ModuleFE as FE

# %%
FE.Parameters.nDof=3

# %%
n1=FE.Node(1,[0,0,0])
n2=FE.Node(2,[2,0,0])
n3=FE.Node(3,[2,2,0])
n4=FE.Node(4,[0,2,0])
n5=FE.Node(5,[0,0,2])
n6=FE.Node(6,[2,0,2])
n7=FE.Node(7,[2,2,2])
n8=FE.Node(8,[0,2,2])

# %%
m1=FE.Material(96,1/3,1, type='Iso')

# %%
m1

# %%
m1.Emat
# Out:
# array([[144.,  72.,  72.,   0.,   0.,   0.],
#        [ 72., 144.,  72.,   0.,   0.,   0.],
#        [ 72.,  72., 144.,   0.,   0.,   0.],
#        [  0.,   0.,   0.,  36.,   0.,   0.],
#        [  0.,   0.,   0.,   0.,  36.,   0.],
#        [  0.,   0.,   0.,   0.,   0.,  36.]])

# %%
t1=FE.Brick(1,[n1,n2,n3,n4,n5,n6,n7,n8], m1, load_direction=[1,0,0], samplingPoints=2)

# %%
t1.Kg
# Out:
# array([[ 4.67430830e+01,  1.80000000e+01,  1.80000000e+01,
#         -1.97430830e+01,  6.00000000e+00,  6.00000000e+00,
#         -1.63754941e+01, -1.80000000e+01,  3.00000000e+00,
#          7.37549407e+00, -6.00000000e+00,  9.00000000e+00,
#          1.25059289e+01,  9.00000000e+00, -6.00000000e+00,
#         -1.85059289e+01,  3.00000000e+00, -1.80000000e+01,
#         -1.73754941e+01, -1.20000000e+01, -9.00000000e+00,
#          5.37549407e+00,  1.15185639e-15, -3.00000000e+00],
#        [ 1.80000000e+01,  5.51857708e+01,  2.00000000e+01,
#         -6.00000000e+00,  1.68142292e+01,  1.00000000e+01,
#         -1.80000000e+01, -2.13438735e+01,  4.00000000e+00,
#          6.00000000e+00, -3.26561265e+01,  8.00000000e+00,
#          9.00000000e+00,  1.21264822e+01, -8.00000000e+00,
#         -3.00000000e+00, -1.26482213e-01, -4.00000000e+00,
#         -1.50000000e+01, -1.33438735e+01, -1.00000000e+01,
#          9.00000000e+00, -1.66561265e+01, -2.00000000e+01],
# ...

# %%
t1.V
# Out:
# 8.0

# %%
t1.F_fe_global
# Out:
# array([1.11111111, 0.        , 0.        , 1.22222222, 0.        ,
#        0.        , 0.88888889, 0.        , 0.        , 0.77777778,
#        0.        , 0.        , 1.11111111, 0.        , 0.        ,
#        1.22222222, 0.        , 0.        , 0.88888889, 0.        ,
#        0.        , 0.77777778, 0.        , 0.        ])

# %%
t1.element_visualization()
